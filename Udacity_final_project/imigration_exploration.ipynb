# %% [markdown]
# # Data Exploration

# %% [markdown]
# ## Importing libraries and data

# %%
import pandas as pd
pd.set_option('display.max_columns', 500)
pd.set_option('display.max_rows', 500)

# %%
import findspark
findspark.init()
from pyspark.sql import SparkSession

spark = SparkSession.builder.appName("imigration-exploration-spark").getOrCreate()
# Out:
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 23/03/26 13:39:42 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 23/03/26 13:39:42 WARN Utils: Service 'SparkUI' could not bind on port 4040. Attempting port 4041.

# %%
df_i = spark.read.parquet('/Users/felipeaugustonogueira/Documents/personal/imigration_exploration/imigration_parquet')
df_i.createOrReplaceTempView("imigration")
# Out:
# 23/03/26 13:40:31 WARN package: Truncated the string representation of a plan since it was too large. This behavior can be adjusted by setting 'spark.sql.debug.maxToStringFields'.

# %% [markdown]
# Total number of rows on the DataFrame.

# %%
num_rows = df_i.count()
num_rows
# Out:
# 3096313

# %%
spark.sql("""
SELECT
    *
FROM imigration
LIMIT 5
"""
).toPandas().head(4)
# Out:
#        cicid   i94yr  i94mon  i94cit  i94res i94port  arrdate  i94mode  \
# 0  5748517.0  2016.0     4.0   245.0   438.0     LOS  20574.0      1.0
# 1  5748518.0  2016.0     4.0   245.0   438.0     LOS  20574.0      1.0
# 2  5748519.0  2016.0     4.0   245.0   438.0     LOS  20574.0      1.0
# 3  5748520.0  2016.0     4.0   245.0   438.0     LOS  20574.0      1.0
#
#   i94addr  depdate  i94bir  i94visa  count  dtadfile visapost occup entdepa  \
# 0      CA  20582.0    40.0      1.0    1.0  20160430      SYD  None       G
# 1      NV  20591.0    32.0      1.0    1.0  20160430      SYD  None       G
# 2      WA  20582.0    29.0      1.0    1.0  20160430      SYD  None       G
# 3      WA  20588.0    29.0      1.0    1.0  20160430      SYD  None       G
#
#   entdepd entdepu matflag  biryear   dtaddto gender insnum airline  \
# 0       O    None       M   1976.0  10292016      F   None      QF
# 1       O    None       M   1984.0  10292016      F   None      VA
# 2       O    None       M   1987.0  10292016      M   None      DL
# 3       O    None       M   1987.0  10292016      F   None      DL
#
#          admnum  fltno visatype
# 0  9.495387e+10  00011       B1
# 1  9.495562e+10  00007       B1
# 2  9.495641e+10  00040       B1
# 3  9.495645e+10  00040       B1

# %% [markdown]
# ## Data Exploration
# Which is the windows of time considered in the `i94yr` and `i94mon`?<br>
# _Very small period of april, 2016._

# %%
spark.sql("""
SELECT DISTINCT
    i94yr
FROM imigration
""").toPandas().head()
# Out:
# [Stage 6:================================================>        (12 + 2) / 14]
#     i94yr
# 0  2016.0

# %%
spark.sql("""
SELECT DISTINCT
    i94mon
FROM imigration
""").toPandas().head()
# Out:
#    i94mon
# 0     4.0

# %% [markdown]
# Is the column `cicid` a good candidate for an imigrant id?<br>
# _There are no duplicates on this column. So it is ok to use it as an id column._

# %%
spark.sql("""
SELECT
    cicid,
    COUNT(cicid) AS count_cicid
FROM imigration
GROUP BY 1
ORDER BY 2 DESC
""").toPandas().head()
# Out:
#        cicid  count_cicid
# 0  5748877.0            1
# 1  5749231.0            1
# 2  5749277.0            1
# 3  5750090.0            1
# 4  5750830.0            1

# %% [markdown]
# How many occupations type do we have in this dataset?<br>
# _There are only 5. The number of rows with this information does not represent even 1% of the dataset. So, it can not be used to retrieve any significant information._

# %%
spark.sql("""
SELECT
    occup,
    COUNT(occup) AS count_occup
FROM imigration
GROUP BY 1
ORDER BY 2 DESC
""").toPandas().head()
# Out:
#   occup  count_occup
# 0   STU         4719
# 1   OTH          661
# 2   NRR          345
# 3   MKT          280
# 4   EXA          196

# %%
spark.sql("""
WITH occup AS (
SELECT
    occup,
    COUNT(occup) AS count_occup
FROM imigration
GROUP BY 1
ORDER BY 2 DESC
)
SELECT
    SUM(count_occup) AS num_registers
FROM occup
""").toPandas().head()
# Out:
#    num_registers
# 0           8126

# %%
(8126/num_rows)*100
# Out:
# 0.2624411679310199

# %% [markdown]
# In the imigration dataset we have the column that refers to the port itself (`i94port`) and one refering to the transportation modal (`i94mode`). Do we have cases of one `i94port` id having more than one type of transportation modal?<br>
# _By what we can see below we can have people arriving at the same place by more than one type of transportation modal. So, when performing joins with the airport dataset, we have to be cautious to not attribute an airport to an imigrant when he could have arrived by another transportation modal. In this case, we have to perform the JOIN operation using two columns `i94port` and `i94mode`._

# %%
spark.sql("""
WITH counting_modes AS (
SELECT DISTINCT
    i94port,
    i94mode
FROM imigration
)
SELECT
    i94port,
    COUNT(i94mode) AS count_port_modals
FROM counting_modes
GROUP BY 1
ORDER BY 2 DESC
""").toPandas().head()
# Out:
#   i94port  count_port_modals
# 0     FMY                  4
# 1     SPM                  4
# 2     DET                  4
# 3     AGA                  4
# 4     SFR                  4

# %%
spark.sql("""
SELECT DISTINCT
    i94port,
    i94mode
FROM imigration
WHERE i94port = 'SFR'
""").toPandas().head()
# Out:
#   i94port  i94mode
# 0     SFR      NaN
# 1     SFR      2.0
# 2     SFR      3.0
# 3     SFR      9.0
# 4     SFR      1.0

# %% [markdown]
# Which are the most common ports of arrival for aerial mode?<br>
# _There is a little problem here. Since we are looking at arrivals at US it does not make much sense to see an airport from Lagos, Nigeria in the list. This tells us that the list in `i94port` on imigrant dataset does not seems to talk to the `iata_codes` at the airports codes dataset. We will have to adjust that by hand. Look at the ports id and adjust it by hand. For example: LOS as Los Angeles and NYC as New York._

# %%
# Ports with most arrivals
spark.sql("""
SELECT
    i94port,
    SUM(count) AS most_arrivals_at
FROM imigration
WHERE i94mode = 1
GROUP BY 1
ORDER BY 2 DESC
""").toPandas().head(10)
# Out:
#   i94port  most_arrivals_at
# 0     NYC          484299.0
# 1     MIA          340361.0
# 2     LOS          308939.0
# 3     SFR          151904.0
# 4     ORL          147752.0
# 5     NEW          135636.0
# 6     HHW          135565.0
# 7     CHI          129771.0
# 8     HOU           99861.0
# 9     FTL           93842.0

# %%
df_a = spark.read.option("header","true").csv('/Users/felipeaugustonogueira/Documents/personal/imigration_exploration/airport-codes_csv.csv')
df_a.createOrReplaceTempView("airports")

# %%
spark.sql("""
SELECT
    *
FROM airports LIMIT 5
""").toPandas().head()
# Out:
#   ident           type                                name elevation_ft  \
# 0   00A       heliport                   Total Rf Heliport           11
# 1  00AA  small_airport                Aero B Ranch Airport         3435
# 2  00AK  small_airport                        Lowell Field          450
# 3  00AL  small_airport                        Epps Airpark          820
# 4  00AR         closed  Newport Hospital & Clinic Heliport          237
#
#   continent iso_country iso_region  municipality gps_code iata_code  \
# 0        NA          US      US-PA      Bensalem      00A      None
# 1        NA          US      US-KS         Leoti     00AA      None
# 2        NA          US      US-AK  Anchor Point     00AK      None
# 3        NA          US      US-AL       Harvest     00AL      None
# 4        NA          US      US-AR       Newport     None      None
#
#   local_code                            coordinates
# 0        00A     -74.93360137939453, 40.07080078125
# 1       00AA                 -101.473911, 38.704022
# 2       00AK            -151.695999146, 59.94919968
# 3       00AL  -86.77030181884766, 34.86479949951172
# 4       None                    -91.254898, 35.6087

# %%
# Ports with most arrivals on the airports codes dataset.
spark.sql("""
SELECT
    type,
    name,
    municipality,
    iso_country,
    iata_code, 
    local_code,
    ident
FROM airports
WHERE iata_code IN ('NYC', 'MIA', 'LOS', 'SFR', 'ORL', 'NEW', 'HHW', 'CHI', 'HOU', 'FTL')
""").toPandas().head()
# Out:
#              type                                    name municipality  \
# 0   large_airport  Murtala Muhammed International Airport        Lagos
# 1   large_airport                 William P Hobby Airport      Houston
# 2   large_airport             Miami International Airport        Miami
# 3  medium_airport                       Lakefront Airport  New Orleans
# 4   small_airport               Orlando Executive Airport      Orlando
#
#   iso_country iata_code local_code ident
# 0          NG       LOS       None  DNMM
# 1          US       HOU        HOU  KHOU
# 2          US       MIA        MIA  KMIA
# 3          US       NEW        NEW  KNEW
# 4          US       ORL        ORL  KORL

# %%
spark.sql("""
SELECT
    i94port,
    COUNT(i94port) AS count_arrivals,
    (COUNT(i94port)/3096313)*100 AS percent
FROM imigration
GROUP BY 1
ORDER BY 2 DESC
""").toPandas().head(30)
# Out:
#    i94port  count_arrivals    percent
# 0      NYC          485916  15.693375
# 1      MIA          343941  11.108082
# 2      LOS          310163  10.017172
# 3      SFR          152586   4.927990
# 4      ORL          149195   4.818473
# 5      HHW          142720   4.609353
# 6      NEW          136122   4.396261
# 7      CHI          130564   4.216757
# 8      HOU          101481   3.277479
# 9      FTL           95977   3.099719
# 10     ATL           92579   2.989975
# 11     LVG           89280   2.883429
# 12     AGA           80919   2.613399
# 13     WAS           74835   2.416907
# 14     DAL           71809   2.319178
# 15     BOS           57354   1.852332
# 16     SEA           47719   1.541156
# 17     PHO           38890   1.256010
# 18     DET           37832   1.221840
# 19     TAM           25632   0.827823
# 20     PHI           24973   0.806540
# 21     DUB           24371   0.787097
# 22     SAI           23628   0.763101
# 23     TOR           20886   0.674544
# 24     DEN           18260   0.589734
# 25     MAA           18151   0.586213
# 26     PSP           18117   0.585115
# 27     FMY           17514   0.565640
# 28     SPM           16973   0.548168
# 29     CLT           16228   0.524107

# %%
df_sas = spark.read \
    .option("header","true") \
    .option("delimiter", "|") \
    .csv('/Users/felipeaugustonogueira/Documents/personal/imigration_exploration/sas_descriptive_information.csv')
df_sas.createOrReplaceTempView("sas")

# %% [markdown]
# Generating the name of the city of the ports so we can correct the id when getting the airports names.<br>
# _Looking at the query below we can see that there are some `iata_code` that does not exist (New York, for example) and some others that return the wrong place. Unfortunately, we have no way of knowing from which airport does the imigrant arrives in case we have multiple airports in the city (New York, for example). In this case, the best thing we can do is to discart the airport database and use the information we retrieved from the SAS data base._

# %% [markdown]
# Above we can see the Los Angeles Airport wrongly defined as Murtala Muhammed International Airport, because the i94port for it is LOS. But, in this case the iata code and the i94 information does not match. If it did, the i94port would probrably be LAX. We did tried to adjust the information, but there is no way with what we have so far.

# %%
spark.sql("""
SELECT
    i.i94port,
    s.description AS port_city,
    a.iata_code,
    a.iso_country,
    a.name,
    COUNT(i.i94port) AS count_arrivals,
    ROUND((COUNT(i.i94port)/3096313)*100,2) AS percent
FROM imigration i
LEFT JOIN sas s ON s.id = i.i94port AND s.column = 'i94port'
LEFT JOIN airports a ON a.iata_code = i.i94port
GROUP BY 1, 2, 3, 4, 5
ORDER BY 6 DESC
""").toPandas().head(20)
# Out:
#    i94port             port_city iata_code iso_country  \
# 0      NYC          NEW YORK, NY      None        None
# 1      MIA             MIAMI, FL       MIA          US
# 2      LOS       LOS ANGELES, CA       LOS          NG
# 3      SFR     SAN FRANCISCO, CA       SFR          US
# 4      ORL           ORLANDO, FL       ORL          US
# 5      HHW          HONOLULU, HI      None        None
# 6      NEW  NEWARK/TETERBORO, NJ       NEW          US
# 7      CHI           CHICAGO, IL      None        None
# 8      HOU           HOUSTON, TX       HOU          US
# 9      FTL   FORT LAUDERDALE, FL      None        None
# 10     ATL           ATLANTA, GA       ATL          US
# 11     LVG         LAS VEGAS, NV      None        None
# 12     AGA             AGANA, GU       AGA          MA
# 13     WAS         WASHINGTON DC      None        None
# 14     DAL            DALLAS, TX       DAL          US
# 15     BOS            BOSTON, MA       BOS          US
# 16     SEA           SEATTLE, WA       SEA          US
# 17     PHO           PHOENIX, AZ       PHO          US
# 18     DET           DETROIT, MI       DET          US
# 19     TAM             TAMPA, FL       TAM          MX
#
#                                                  name  count_arrivals  percent
# 0                                                None          485916    15.69
# 1                         Miami International Airport          343941    11.11
# 2              Murtala Muhammed International Airport          310163    10.02
# 3                                San Fernando Airport          152586     4.93
# 4                           Orlando Executive Airport          149195     4.82
# 5                                                None          142720     4.61
# 6                                   Lakefront Airport          136122     4.40
# 7                                                None          130564     4.22
# 8                             William P Hobby Airport          101481     3.28
# 9                                                None           95977     3.10
# 10   Hartsfield Jackson Atlanta International Airport           92579     2.99
# 11                                               None           89280     2.88
# 12                                 Al Massira Airport           80919     2.61
# 13                                               None           74835     2.42
# 14                                  Dallas Love Field           71809     2.32
# 15  General Edward Lawrence Logan International Ai...           57354     1.85
# 16               Seattle Tacoma International Airport           47719     1.54
# 17                                 Point Hope Airport           38890     1.26
# 18                 Coleman A. Young Municipal Airport           37832     1.22
# 19  General Francisco Javier Mina International Ai...           25632     0.83

# %%
spark.sql("""
WITH adj_query AS (
    SELECT
        i.i94port,
        s.description AS port_city,
        a.iata_code,
        a.iso_country,
        a.name,
        COUNT(i.i94port) AS count_arrivals,
        ROUND((COUNT(i.i94port)/3096313)*100,2) AS percent
    FROM imigration i
    LEFT JOIN sas s ON s.id = i.i94port AND s.column = 'i94port'
    LEFT JOIN airports a ON a.iata_code = i.i94port
    GROUP BY 1, 2, 3, 4, 5
    ORDER BY 6 DESC LIMIT 20
)
SELECT
    SUM(percent)
FROM adj_query
""").toPandas().head()
# Out:
#    sum(percent)
# 0          86.1

# %%
spark.sql("""
WITH adj_query AS (
    SELECT
        i.i94port,
        i.i94mode,
        s.description AS port_city,
        a.iata_code,
        a.iso_country,
        a.name,
        COUNT(i.i94port) AS count_arrivals,
        ROUND((COUNT(i.i94port)/3096313)*100,2) AS percent
    FROM imigration i
    LEFT JOIN sas s ON s.id = i.i94port AND s.column = 'i94port'
    LEFT JOIN airports a ON a.iata_code = i.i94port
    WHERE i.i94mode = 1
    GROUP BY 1, 2, 3, 4, 5, 6
    ORDER BY 7 DESC LIMIT 20
),
imig_base_city AS (
SELECT DISTINCT
    i94port,
    LOWER(SPLIT(port_city,',')[0]) AS city
FROM adj_query
), final AS (
SELECT
    i.i94port,
    i.city,
    LOWER(a.municipality) AS municipality,
    a.iata_code
FROM imig_base_city i
LEFT JOIN airports a ON LOWER(municipality) = i.city
)
SELECT
    * 
FROM final
""").toPandas().head(100)
# Out:
#    i94port         city municipality iata_code
# 0      NYC     new york     new york      None
# 1      NYC     new york     new york      None
# 2      NYC     new york     new york      None
# 3      NYC     new york     new york      None
# 4      NYC     new york     new york       LGA
# 5      NYC     new york     new york       JFK
# 6      NYC     new york     new york       JRB
# 7      NYC     new york     new york       JRA
# 8      NYC     new york     new york       JPB
# 9      NYC     new york     new york       QNY
# 10     NYC     new york     new york      None
# 11     NYC     new york     new york       TSS
# 12     MIA        miami        miami      None
# 13     MIA        miami        miami       MPB
# 14     MIA        miami        miami      None
# 15     MIA        miami        miami       TNT
# 16     MIA        miami        miami       TMB
# 17     MIA        miami        miami       OPF
# 18     MIA        miami        miami      None
# 19     MIA        miami        miami       MIA
# 20     MIA        miami        miami      None
# 21     MIA        miami        miami      None
# 22     MIA        miami        miami      None
# 23     MIA        miami        miami      None
# 24     MIA        miami        miami      None
# 25     MIA        miami        miami      None
# 26     MIA        miami        miami      None
# 27     MIA        miami        miami      None
# 28     MIA        miami        miami      None
# 29     MIA        miami        miami      None
# 30     MIA        miami        miami      None
# 31     MIA        miami        miami      None
# 32     MIA        miami        miami      None
# 33     MIA        miami        miami      None
# 34     MIA        miami        miami      None
# 35     MIA        miami        miami      None
# 36     MIA        miami        miami      None
# 37     MIA        miami        miami      None
# 38     MIA        miami        miami      None
# 39     MIA        miami        miami      None
# 40     LOS  los angeles  los angeles      None
# 41     LOS  los angeles  los angeles      None
# 42     LOS  los angeles  los angeles      None
# 43     LOS  los angeles  los angeles       SFR
# 44     LOS  los angeles  los angeles      None
# 45     LOS  los angeles  los angeles       LSQ
# 46     LOS  los angeles  los angeles       WHP
# 47     LOS  los angeles  los angeles       LAX
# 48     LOS  los angeles  los angeles      None
# 49     LOS  los angeles  los angeles      None
# 50     LOS  los angeles  los angeles      None
# 51     LOS  los angeles  los angeles      None
# 52     LOS  los angeles  los angeles      None
# 53     LOS  los angeles  los angeles      None
# 54     LOS  los angeles  los angeles      None
# 55     LOS  los angeles  los angeles      None
# 56     LOS  los angeles  los angeles      None
# 57     LOS  los angeles  los angeles      None
# 58     LOS  los angeles  los angeles      None
# 59     LOS  los angeles  los angeles      None
# 60     LOS  los angeles  los angeles      None
# 61     LOS  los angeles  los angeles      None
# 62     LOS  los angeles  los angeles      None
# 63     LOS  los angeles  los angeles      None
# 64     LOS  los angeles  los angeles      None
# 65     LOS  los angeles  los angeles      None
# 66     LOS  los angeles  los angeles      None
# 67     LOS  los angeles  los angeles      None
# 68     LOS  los angeles  los angeles      None
# 69     LOS  los angeles  los angeles      None
# 70     LOS  los angeles  los angeles       CCD
# 71     LOS  los angeles  los angeles      None
# 72     LOS  los angeles  los angeles      None
# 73     LOS  los angeles  los angeles      None
# 74     LOS  los angeles  los angeles      None
# 75     LOS  los angeles  los angeles      None
# 76     LOS  los angeles  los angeles      None
# 77     LOS  los angeles  los angeles      None
# 78     LOS  los angeles  los angeles      None
# 79     LOS  los angeles  los angeles      None
# 80     LOS  los angeles  los angeles      None
# 81     LOS  los angeles  los angeles      None
# 82     LOS  los angeles  los angeles      None
# 83     LOS  los angeles  los angeles      None
# 84     LOS  los angeles  los angeles      None
# 85     LOS  los angeles  los angeles      None
# 86     LOS  los angeles  los angeles      None
# 87     LOS  los angeles  los angeles      None
# 88     LOS  los angeles  los angeles      None
# 89     LOS  los angeles  los angeles      None
# 90     LOS  los angeles  los angeles      None
# 91     LOS  los angeles  los angeles      None
# 92     LOS  los angeles  los angeles      None
# 93     LOS  los angeles  los angeles      None
# 94     LOS  los angeles  los angeles      None
# 95     LOS  los angeles  los angeles      None
# 96     LOS  los angeles  los angeles      None
# 97     LOS  los angeles  los angeles      None
# 98     LOS  los angeles  los angeles      None
# 99     LOS  los angeles  los angeles      None

# %% [markdown]
# Above, we have multiple ports in New York city. How do we know from which the imigrant arrived in the US?<br>
# If there is no way of knowing, and the only information we can retrieve is the city, it would be better to get the city information from the SAS .csv file where we can have the city for every i94port id.

# %%
spark.sql("""
SELECT
    *
FROM airports
WHERE municipality = 'New York'
""").toPandas().head(20)
# Out:
#       ident           type                                               name  \
# 0       6N5       heliport                          East 34th Street Heliport
# 1       6N6  seaplane_base                                Evers Seaplane Base
# 2       6N7  seaplane_base                New York Skyports Inc Seaplane Base
# 3       JPB         closed                           Pan Am Building Heliport
# 4       JRA       heliport                             West 30th St. Heliport
# 5       JRB       heliport                Downtown-Manhattan/Wall St Heliport
# 6      KJFK  large_airport               John F Kennedy International Airport
# 7      KLGA  large_airport                                 La Guardia Airport
# 8      KNOP         closed                                Floyd Bennett Field
# 9      NK39       heliport                          One Police Plaza Heliport
# 10     NY22       heliport  NYPD Air Operations (Floyd Bennett Field) Heli...
# 11  US-0883  large_airport                                                JFK
#
#    elevation_ft continent iso_country iso_region municipality gps_code  \
# 0            10        NA          US      US-NY     New York      6N5
# 1          None        NA          US      US-NY     New York      6N6
# 2          None        NA          US      US-NY     New York     None
# 3           870        NA          US      US-NY     New York     None
# 4             7        NA          US      US-NY     New York     KJRA
# 5             7        NA          US      US-NY     New York     KJRB
# 6            13        NA          US      US-NY     New York     KJFK
# 7            21        NA          US      US-NY     New York     KLGA
# 8            16        NA          US      US-NY     New York     None
# 9           244        NA          US      US-NY     New York     NK39
# 10           16        NA          US      US-NY     New York     NY22
# 11         None        NA          US      US-NY     New York     None
#
#    iata_code local_code                            coordinates
# 0        TSS        6N5  -73.97209930419922, 40.74259948730469
# 1       None        6N6  -73.81620025634766, 40.84590148925781
# 2        QNY        6N7                    -73.9729, 40.734001
# 3        JPB       None                      -73.9765, 40.7533
# 4        JRA        JRA                  -74.007103, 40.754501
# 5        JRB        JRB              -74.00900269, 40.70119858
# 6        JFK        JFK              -73.77890015, 40.63980103
# 7        LGA        LGA              -73.87259674, 40.77719879
# 8       None       None                     -73.890999, 40.591
# 9       None       NK39  -73.99960327148438, 40.71260070800781
# 10      None       NY22                      -73.8805, 40.5905
# 11      None       None                                   0, 0
